# %%
import pickle
with open('/home/user/skip/code/nnUNet/nnUNet_trained_models/nnUNet/2d/Task513_DRIVE/nnUNetTrainerV2__nnUNetPlansv2.1/12_25-23_17#ERNET-wDS-epoch300-baseformerV2-E7_D7/plans.pkl', 'rb') as fr:
    data = pickle.load(fr)

# %%
print (data)
# Out:
# {'num_stages': 1, 'num_modalities': 3, 'modalities': {0: 'Red', 1: 'Green', 2: 'Blue'}, 'normalization_schemes': OrderedDict([(0, 'nonCT'), (1, 'nonCT'), (2, 'nonCT')]), 'dataset_properties': {'all_sizes': [(1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 584, 565), (1, 581, 565)], 'all_spacings': [array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,   1.,   1.]), array([999.,  
# ...
